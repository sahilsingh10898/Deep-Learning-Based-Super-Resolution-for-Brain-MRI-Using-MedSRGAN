# %%
import tensorflow as tf
from tensorflow.keras import layers,Model
from tensorflow.keras.layers import *
from tensorflow.keras.applications import VGG19
from tensorflow.keras.losses import MeanSquaredError, MeanAbsoluteError
from tensorflow.image import ssim
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/sahilsingh/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/sahilsingh/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/sahilsingh/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
def guassian_noise(image,mean=0.00,sigma=20): 
    # add guassian noise use tf.random.normal
    noise=tf.random.normal(shape=tf.shape(image),mean=0.00,stddev=0.2,dtype=tf.float32)
    noisy_image=tf.clip_by_value(image+noise,0.0,1.0)
    return noisy_image


def downgrading(image,size=(512,512)):
    
    noisy_image=guassian_noise(image,mean=0.0,sigma=20)
    final=tf.image.resize(noisy_image,size,method='bilinear')
    return final

# %%
def preprocessing(image_path,size=(1024,1024)):
    img=tf.io.read_file(image_path)
    img=tf.image.decode_image(img,channels=3)
    img=tf.image.convert_image_dtype(img,tf.float32)
    img.set_shape([None,None,3])

    img=downgrading(img,size=(512,512))

    high_res=tf.io.read_file(image_path)
    high_res=tf.image.decode_image(high_res,channels=3)
    high_res=tf.image.convert_image_dtype(high_res,tf.float32)
    high_res.set_shape([None,None,3])
    high_res = tf.image.resize(high_res, size, method='bilinear')

    return img,high_res



def create_pipeline(image_path,size=(1024,1024),batch_size=16):
    # use tf.data.Dataset to create the pipeline
    dataset=tf.data.Dataset.from_tensor_slices(image_path)

    dataset=dataset.map(lambda path : preprocessing(path,size=(1024,1024)),num_parallel_calls=tf.data.AUTOTUNE)

    dataset=dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return dataset
    
    
#training_dataset=create_pipeline(train_list,size=(1024,1024),batch_size=16)
#testing_dataset=create_pipeline(test_list,size=(1024,1024),batch_size=16)

# %%
class ResidualAttentionBlock(layers.Layer):
    def __init__(self,filters,**kwargs):
        super(ResidualAttentionBlock,self).__init__(*kwargs)
        self.conv1=layers.Conv2D(filters,kernel_size=3,strides=1,padding='same',activation='relu')
        self.conv2=layers.Conv2D(filters,kernel_size=3,strides=1,padding='same')
        self.attention=layers.Conv2D(1,kernel_size=1,strides=1,padding='same',activation='sigmoid')

    def call(self,inputs):
        #residual connection
        residual=inputs
        # feature extraction
        x=self.conv1(inputs)
        x=self.conv2(x)
        # Whole attention Map

        attention=self.attention(x)
        x=x*attention

        # add residuals
        return x+residual

class SubPixelConv2D(layers.Layer):
    def __init__(self,scale,**kwargs):
        super(SubPixelConv2D,self).__init__(**kwargs)
        self.scale=scale
    
    def call(self,inputs):
        return tf.nn.depth_to_space(inputs,block_size=self.scale)
    
    def get_config(self):
        config=super().get_config()
        config.update({"scale":self.scale})
        return config

# %%
def generator(input_shape=(None,None,3),filters=64,num_res_block=16,scale=4):
    input=layers.Input(shape=input_shape)

    # initial layer
    x=Conv2D(filters,kernel_size=3,strides=1,padding='same')(input)
    skip=x

    for _ in range(num_res_block):
        x=ResidualAttentionBlock(filters)(x)

    # after residual block

    x=Conv2D(filters,kernel_size=3,strides=1,padding='same')(x)
    x=Add()([x,skip]) # add skip connection


    # upsampling using sub-pixel convolution

    for _ in range(int(tf.math.log(float(scale))/tf.math.log(2.0))):
        x= Conv2D(filters*(2**2),kernel_size=3,strides=1,padding='same')(x)
        x=SubPixelConv2D(scale=2)(x)
        x=PReLU(shared_axes=[1,2])(x)

    output=Conv2D(3,kernel_size=9,strides=1,padding='same',activation='sigmoid')(x)
    
    return Model(input,output)

# %%
model=generator(input_shape=(128,128,3),filters=64,num_res_block=16,scale=4)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_attention… │ (None, 128, 128,  │     73,921 │ conv2d[0][0]      │
# │ (ResidualAttention… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
tf.keras.utils.plot_model(model,show_shapes=True,dpi=90)

# %%
def discriminator(hr_img_shape=(None,None,3),lr_img_shape=(None,None,3)):

    
    input_hr=layers.Input(shape=hr_img_shape)
    input_lr=layers.Input(shape=lr_img_shape)

    # for hr images
    x_hr=Conv2D(64,kernel_size=3,strides=1,padding='same')(input_hr)
    x_hr=LeakyReLU(alpha=0.2)(x_hr)

    x_hr=Conv2D(64,kernel_size=3,strides=2,padding='same')(x_hr)
    x_hr=BatchNormalization()(x_hr)
    x_hr=LeakyReLU(alpha=0.2)(x_hr)

    x_hr=Conv2D(128,kernel_size=3,strides=1,padding='same')(x_hr)
    x_hr=BatchNormalization()(x_hr)
    x_hr=LeakyReLU(alpha=0.2)(x_hr)

    x_hr=Conv2D(128,kernel_size=3,strides=2,padding='same')(x_hr)
    x_hr=BatchNormalization()(x_hr)
    x_hr_f=LeakyReLU(alpha=0.2)(x_hr)

    # for low res image

    x_lr=Conv2D(64,kernel_size=3,strides=1,padding='same')(input_lr)
    x_lr=LeakyReLU(alpha=0.2)(x_lr)

    x_lr=Conv2D(128,kernel_size=3,strides=1,padding='same')(x_lr)
    x_lr=BatchNormalization()(x_lr)
    x_lr_f=LeakyReLU(alpha=0.2)(x_lr)

    concat_layer=Concatenate()([x_hr_f,x_lr_f])

    #feature Extraction Layers

    x=Conv2D(256,kernel_size=3,strides=1,padding='same')(concat_layer)
    x=BatchNormalization()(x)
    x=LeakyReLU(alpha=0.2)(x)

    x=Conv2D(256,kernel_size=3,strides=2,padding='same')(x)
    x=BatchNormalization()(x)
    x=LeakyReLU(alpha=0.2)(x)

    x=Conv2D(512,kernel_size=3,strides=1,padding='same')(x)
    x=BatchNormalization()(x)
    x=LeakyReLU(alpha=0.2)(x)

    x=Conv2D(512,kernel_size=3,strides=2,padding='same')(x)
    x=BatchNormalization()(x)
    x=LeakyReLU(alpha=0.2)(x)

    x=Conv2D(1024,kernel_size=3,strides=1,padding='same')(x)
    x=BatchNormalization()(x)
    x=LeakyReLU(alpha=0.2)(x)

    x=Conv2D(1024,kernel_size=3,strides=2,padding='same')(x)
    x=BatchNormalization()(x)
    x=LeakyReLU(alpha=0.2)(x)

    # fully connected Layers

    flaten=Flatten()(x)
    dense1=Dense(100)(flaten)
    dense1=LeakyReLU(alpha=0.2)(dense1)

    dense2=Dense(1,activation='sigmoid')(dense1)

    model=Model([input_hr,input_lr],dense2)

    return model

# %%
model2=discriminator(hr_img_shape=(512,512,3),lr_img_shape=(128,128,3))
model2.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_73 (Conv2D)  │ (None, 512, 512,  │      1,792 │ input_layer_6[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_21      │ (None, 512, 512,  │          0 │ conv2d_73[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# ## Type of losses in the Model
# 1. Content Loss :- Taken from feature extracted from a VGG19 Pre-trained model
# 2. Adversial Loss :- Discriminator Loss
# 3. Pixel Loss :- There will be two types of pixel loss
#    1. MSE
#    2. MAE
# 4. SSIM Loss

# %%
#optim=Adam(0.01,beta_1=0.9,beta_2=0.99)

vgg=VGG19(include_top=False,weights='imagenet')
vgg.trainable=False
content_layer='block5_conv4'
vgg_content=Model(inputs=vgg.input,outputs=vgg.get_layer(content_layer).output)


def content_loss(HR_images,LR_images):

    hr_features=vgg_content(HR_images)
    lr_features=vgg_content(LR_images)

    loss=model_loss(hr_features,lr_features)

    return loss
def adversial_loss(dis_output_real,dis_output_fake):
    real_loss= -tf.reduce_mean(tf.math.log(dis_output_real+1e-9))
    fake_loss=-tf.reduce_mean(tf.math.log(1-dis_output_fake+1e-9))
    return real_loss+fake_loss

def model_loss(LR_image,HR_image):
    loss=tf.reduce_mean(tf.square(HR_image-LR_image))
    return loss


def ssim_loss(HR_image,LR_image):
    loss=-ssim(HR_image,LR_image)
    return loss

def total_variation_loss(image):
    return tf.reduce_sum(tf.image.total_variation(image))

def total_loss(HR_image,LR_image,dis_output,lambda_content=1.0,lambda_adv=0.001,lambda_model=1.0,lambda_ssim=1.0,lambda_tv=1e-6):
    c_loss=lambda_content*content_loss(HR_image,LR_image)
    a_loss=lambda_adv*adversial_loss(dis_output)
    m_loss=lambda_model*model_loss(HR_image,LR_image,dis_output)
    s_loss=lambda_ssim*ssim_loss(HR_image,LR_image,dis_output)
    tv_loss=lambda_tv*total_variation_loss(HR_image)

    return c_loss+ m_loss_+ s_loss_+ tv_loss+ a_loss

# %%
def psnr(LR_image,HR_image):
    # we need to make sure the value of the pixels are normalized
    LR_image=tf.clip_by_value(LR_image,0.0,1.00)
    HR_image=tf.clip_by_value(HR_image,0.0,1.00)
    loss=tf.reduce_mean(tf.square(HR_image-LR_image))
    value=10*tf.math.log(1.0/loss)

    return value


def ssim(LR_image,HR_image):

    LR_image=tf.clip_by_value(LR_image,0.0,1.00)
    HR_image=tf.clip_by_value(HR_image,0.0,1.00)
    ssim_value=tf.image.ssim(LR_image,HR_image,max_val=1.0)
    # :-> since the ssim_value will be calculated for a single image and what we want is ssim value of the batch of images therefore we need to
    # calculate the mean of the ssim values

    value=tf.reduce_mean(ssim_value)

    return value

# %%
def dis_loss(real,fake):
    bce=BinaryCrossentropy(from_logits=True)
    real_loss=bce(tf.ones_like(real),real)
    fake_loss=bce(tf.zeros_like(fake),fake)
    total=real_loss+fake_loss

    return total

# %%
optim_dis=Adam(0.001,beta_1=0.9,beta_2=0.999)
optim_gen=Adam(0.001,beta_1=0.9,beta_2=0.999)


def training(HR_image,LR_image):
    with tf.GradientTape() as gen_tape, tf.GradientTape() as dis_tape:
        # forward pass
        gen_output=generator(LR_image,training=True)

        dis_real_output=discriminator([HR_image,LR_image],training=True)
        dis_fake_output=discriminator([gen_output,LR_image],training=True)

        generator_loss=total_loss(HR_image,LR_image,gen_output)
        discriminator_loss=dis_loss(dis_real_output,dis_fake_output)

    # gradients flow

    generator_gradients=gen_tape.gradients(generator_loss,generator.trainable_variables)
    discriminator_gradients=dis_tape.gradients(discriminator_loss,discriminator.trainable_variables)

    # apply optimization

    optim_gen.apply_gradients(zip(generator_gradients,generator.trainable_variables))
    optim_dis.apply_gradients(zip(discriminator_gradients,discriminator.trainable_variables))

    return generator_loss,discriminator_loss
